# %%
import requests
import time
import re
import string
import nltk
import os
import spacy

import xml.etree.ElementTree as ET
from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from typing import List, Tuple, Dict
from operator import itemgetter
from nltk.corpus import stopwords
from langchain_core.documents import Document
from dotenv import load_dotenv
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.runnables import RunnableParallel, RunnableWithMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

nltk.download("stopwords")
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# load the important credentials from .env file
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_API_KEY")
os.environ["PINECONE_API_KEY"] = os.getenv("PINECONE_API_KEY")

os.environ["LANGSMITH_TRACING"] = os.getenv("LANGSMITH_TRACING")
os.environ["LANGSMITH_ENDPOINT"] = os.getenv("LANGSMITH_ENDPOINT")
os.environ["LANGSMITH_PROJECT"] = os.getenv("LANGSMITH_PROJECT")
os.environ["PINECONE_INDEX_NAME"] = os.getenv("PINECONE_INDEX_NAME")

# %%
# parse the sitemap urls to fetch actual associated urls
def parse_sitemap(content: bytes) -> List[str]:
    """Parse XML sitemap and extract URLs"""
    urls = []
    try:
        root = ET.fromstring(content)

        # Check if it's a sitemap index
        if "sitemapindex" in root.tag:
            for sitemap in root.findall(".//{*}sitemap"):
                loc = sitemap.find("{*}loc")
                if loc is not None:
                    sub_url = loc.text
                    print(f"Fetching: {sub_url}")
                    try:
                        response = requests.get(sub_url, timeout=10)
                        if response.status_code == 200:
                            urls.extend(parse_sitemap(response.content))
                        time.sleep(0.5)
                    except Exception as e:
                        print(f"  Error: {str(e)}")
        else:
            # Regular sitemap with URLs
            for url_elem in root.findall(".//{*}url"):
                loc = url_elem.find("{*}loc")
                if loc is not None:
                    urls.append(loc.text)
            print(f"Found {len(urls)} URLs in this sitemap")

    except ET.ParseError as e:
        print(f"Error parsing XML: {str(e)}")

    return urls

# %%
# fetch all sitemap urls from baseurl
def fetch_sitemap_urls(base_url: str)-> Tuple[str]:
    """Fetch sitemap URLs from the base URL"""
    urls = []
    
    # trailing slash 
    if not base_url.endswith("/"):
        base_url += "/"
    
    # common sitemap locations
    sitemap_urls = [
        f"{base_url}sitemap.xml",
        f"{base_url}sitemap_index.xml",
        f"{base_url}sitemap-index.xml",
        f"{base_url}wp-sitemap.xml",
    ]
    for url in sitemap_urls:
        try:
            response = requests.get(url, timeout=10)
            if response.status_code == 200:
                urls = parse_sitemap(response.content)
                break
        except Exception as e:
            print(f"Error in {url}: {e}")
    
    all_urls = tuple(urls)
    return all_urls

# %%
regromedia_urls = fetch_sitemap_urls(base_url="https://www.regromedia.com/")
regromedia_urls
# Out:
# Found 19 URLs in this sitemap
# ('https://www.regromedia.com/',
#  'https://www.regromedia.com/case-studies',
#  'https://www.regromedia.com/casestudy',
#  'https://www.regromedia.com/404',
#  'https://www.regromedia.com/pricing-details',
#  'https://www.regromedia.com/shipping-policy',
#  'https://www.regromedia.com/refund-policy',
#  'https://www.regromedia.com/privacy-policy',
#  'https://www.regromedia.com/privacy-policy-2',
#  'https://www.regromedia.com/terms-and-conditions',
#  'https://www.regromedia.com/case-studies/skin-care-brand',
#  'https://www.regromedia.com/case-studies/this-premium-clothing-brand-s-amazon-success-story',
#  'https://www.regromedia.com/case-studies/plant-protien-brand',
#  'https://www.regromedia.com/case-studies/famerugs',
#  'https://www.regromedia.com/case-studies/tripoles-amazon-success-story',
#  'https://www.regromedia.com/case-studies/scaled-this-baby-care-brand-to-new-hights',
#  'https://www.regromedia.com/case-studies/this-body-warmer-brand',
#  'https://www.regromedia.com/case-studies/golden-bee',
#  'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization')

# %%
loader = WebBaseLoader(
    web_paths=regromedia_urls
)
data = loader.load()

# %%
# Text Cleaning and processing
# Step 1 -> remove url
def remove_url(text: str)-> str:
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub(r'', text)

# Step 2 -> Punctuation handleing
exclude_punc = string.punctuation

def remove_punc(text: str)-> str:
    return text.translate(str.maketrans('', '', exclude_punc))

# Step 3 -> Chat conversion handle
chat_words = {
    "FYI": "For Your Information",
    "ASAP": "As Soon As Possible",
    "BRB": "Be Right Back",
    "BTW": "By The Way",
    "OMG": "Oh My God",
    "IMO": "In My Opinion",
    "LOL": "Laugh Out Loud",
    "TTYL": "Talk To You Later",
    "GTG": "Got To Go",
    "TTYT": "Talk To You Tomorrow",
    "IDK": "I Don't Know",
    "TMI": "Too Much Information",
    "IMHO": "In My Humble Opinion",
    "ICYMI": "In Case You Missed It",
    "AFAIK": "As Far As I Know",
    "BTW": "By The Way",
    "FAQ": "Frequently Asked Questions",
    "TGIF": "Thank God It's Friday",
    "FYA": "For Your Action",
    "ICYMI": "In Case You Missed It",
}

def chat_conversion(text: str)-> str:
    new_text = []
    for word in text.split():
        if word.upper() in chat_words:
            new_text.append(chat_words[word.upper()])
        else:
            new_text.append(word)
    return " ".join(new_text)

# Step 4 -> Normalize whitespace
def normalize_whitespace(text: str)-> str:
    return " ".join(text.split())

# Step 5: Stopwords
def remove_stopwords(text: str)-> str:
    new_text = []
    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    return " ".join(new_text)


# Step 6: Remove emojis
def remove_emoji(text):
    emoji_pattern = re.compile(
        "["
        "\U0001f600-\U0001f64f"  # emoticons
        "\U0001f300-\U0001f5ff"  # symbols & pictographs
        "\U0001f680-\U0001f6ff"  # transport & map symbols
        "\U0001f1e0-\U0001f1ff"  # flags (iOS)
        "\U00002702-\U000027b0"
        "\U000024c2-\U0001f251"
        "]+",
        flags=re.UNICODE,
    )
    return emoji_pattern.sub(r"", text)


# Step 7 -> Lemmatization spaCy
def lemmatize_text_spacy(text: str) -> str:
    doc = nlp(text)
    return " ".join(token.lemma_ for token in doc)

# %%
def clean_page_text(text: str) -> str:
    """Run the full text cleaning pipeline on a single string."""

    # 1. Remove URLs
    text = remove_url(text)
    # 2. Remove emojis
    text = remove_emoji(text)
    # 3. Expand chat abbreviations (FYI → For Your Information)
    text = chat_conversion(text)
    # # 4. Remove punctuation
    # text = remove_punc(text)
    # # 5. Remove stopwords
    # text = remove_stopwords(text)
    # NB: not required in modern days 
    # 6. Normalize whitespace
    text = normalize_whitespace(text)
    # 7. Lemmatization
    text = lemmatize_text_spacy(text)
    return text

# %%
def clean_documents(docs):
    """
    Clean page_content of each Document while preserving metadata.
    """
    cleaned = []
    for doc in docs:
        cleaned.append(
            Document(
                page_content=clean_page_text(doc.page_content),
                metadata=doc.metadata,
            )
        )
    return cleaned

# %%
regro_media_cleaned_data = clean_documents(data)

for i, doc in enumerate(regro_media_cleaned_data):
    print(f"\n--- DOCUMENT {i+1} ---")
    print(doc.page_content)
    print(doc.metadata)
# Out:
# --- DOCUMENT 1 ---
# Regro medium last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call Back#1 Amazon ADS Agency in india200 + 5 Star ReviewsTheBestAwardedAmazonAdsAgency . experience our award - win , holistic approach to maximize visibility , conversion , and ROI for your brandschedule a CallSchedule a CallBest AmazonAds Agency play video know about US agenceeserviceswhat we be offeringserviceswhat we be offeringschedule a CallAdvertising ManagementRegro Media have be award as the Best perform agency for Q1,Q2 & Q4 by Amazon itself . our Team of Experts have be certify to handle any Adverse Problems and solve it weather it be Amazon Ads or DSP learn MoreAdvertising ManagementRegro Media have be award as the Best perform agency for Q1,Q2 & Q4 by Amazon itself . our Team of Experts have be certify to handle any Adverse Problems and solve it weather it be Amazon Ads or DSP Learn MoreImages & Creatives we can help , whether its a+ content list image or Premium A+ Content , Brand Story , Brand Store or Video . our expert be experience to generate high converting creative for your brand . Learn MoreImages & Creatives we can help , whether its a+ content list image or Premium A+ Content , Brand Story , Brand Store or Video . our expert be experience to generate high converting creative for your brand . Learn MoreTraining & CoachingLearn the top strategy we use ForManaging over $ 150 + million in revenue . join the top 10 % of Amazon Sellers make profit with great ROI & Conversion Rate with our Proven design sop’s . Learn MoreTraining & CoachingLearn the top strategy we use ForManaging over $ 150 + million in revenue . join the top 10 % of Amazon Sellers make profit with great ROI & Conversion Rate with our Proven design sop’s . learn MoreSEO & Listing optimizationWe understand the importance of seo in maximize your Amazon list 's potential and help secure the high Ranking Juice in your niche with our advanced Help!Learn MoreSEO & Listing optimizationWe understand the importance of seo in maximize your Amazon list 's potential and help secure the high Ranking Juice in your niche with our advanced help!learn moreserviceswhat we be offeringschedule a CallAdvertising ManagementRegro Media have be award as the Best perform agency for Q1,Q2 & Q4 by Amazon itself . our Team of Experts have be certify to handle any Adverse Problems and solve it weather it be Amazon Ads or DSP Learn MoreImages & Creatives we can help , whether its a+ content list image or Premium A+ Content , Brand Story , Brand Store or Video . our expert be experience to generate high converting creative for your brand . Learn MoreTraining & CoachingLearn the top strategy we use ForManaging over $ 150 + million in revenue . join the top 10 % of Amazon Sellers make profit with great ROI & Conversion Rate with our Proven design sop’s . learn MoreSEO & Listing optimizationWe understand the importance of seo in maximize your Amazon list 's potential and help secure the high Ranking Juice in your niche with our advanced help!learn MoreBrands CollaboraationsBrands that trust usbrand CollaboraationsBrands that trust us8+Years of experience200+successful projects180+happy clients35+member TeamProven Track RecordWe have build a reputation as a trusted and reliable partner in achieve business success . proven Track RecordWe have build a reputation as a trusted and reliable partner in achieve business success . tailor solutionswe offer personalize solution tailor to your specific goal , audience , and industry . tailor solutionswe offer personalize solution tailor to your specific goal , audience , and industry . Client - Centric FocusYour success be our priority . we prioritize understand your business goal . Client - Centric FocusYour success be our priority . we prioritize understand your business goal ...
# {'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 2 ---
# Regro medium last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackCheck our Works with Real ResultsCheck our Works with Real ResultsCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%TACOSCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%tacoslearn MoreCase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % tacoscase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % TACOSLearn MoreCase StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%case StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%learn MoreCase studyfame rugs on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,case studyfame RUGS on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,learn MoreCase StudyTripole 's Amazon Success Story : from Challenges to Market DominationHow it manage Low CTR , High ACOS in such competitive market .33.33%Sales growth in 5 Months67 % increase in OrdervolumeCase StudyTripole 's Amazon Success Story : from Challenges to Market DominationHow it manage Low CTR , High ACOS in such competitive market .33.33%Sales growth in 5 Months67 % increase in OrdervolumeLearn MoreCase StudyScaled this Baby Care Brand to new hight . from Challenges to Market Place domination.123%growth in Revenue 30%roas ImprovementCase StudyScaled this Baby Care Brand to new hight . from Challenges to Market Place domination.123%growth in Revenue 30%roas ImprovementLearn MoreCase studythis Body Warmer Brand see sale Growth with Lowe Task . a Data - back Growth Strategy that deliver Exceptional Results68 % organic order increase 38.10%reduced CPCCase studythis Body Warmer Brand see sale Growth with Lowe Task . a Data - back Growth Strategy that deliver Exceptional Results68 % organic order increase 38.10%Reduced CPCLearn MoreCase StudyGolden Bee , a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosCase StudyGolden Bee , a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosLearn MoreCase StudyHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace Optimization . this Premium BabyCare 's aim to strengthen its brand visibility , increase revenue , and maintain profitability through efficient ad spend management.1 Crore INR Advertisement sale 8%tacoscase StudyHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace Optimization . this Premium BabyCare 's aim to strengthen its brand visibility , increase revenue , and maintain p ...
# {'source': 'https://www.regromedia.com/case-studies', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 3 ---
# Regro medium last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackCheck our Works with Real ResultsCheck our Works with Real ResultsCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%TACOSCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%tacoslearn MoreCase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % tacoscase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % TACOSLearn MoreCase StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%case StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%learn MoreCase studyfame rugs on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,case studyfame RUGS on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,learn MoreCase StudyTripole 's Amazon Success Story : from Challenges to Market DominationHow it manage Low CTR , High ACOS in such competitive market .33.33%Sales growth in 5 Months67 % increase in OrdervolumeCase StudyTripole 's Amazon Success Story : from Challenges to Market DominationHow it manage Low CTR , High ACOS in such competitive market .33.33%Sales growth in 5 Months67 % increase in OrdervolumeLearn MoreCase StudyScaled this Baby Care Brand to new hight . from Challenges to Market Place domination.123%growth in Revenue 30%roas ImprovementCase StudyScaled this Baby Care Brand to new hight . from Challenges to Market Place domination.123%growth in Revenue 30%roas ImprovementLearn MoreCase studythis Body Warmer Brand see sale Growth with Lowe Task . a Data - back Growth Strategy that deliver Exceptional Results68 % organic order increase 38.10%reduced CPCCase studythis Body Warmer Brand see sale Growth with Lowe Task . a Data - back Growth Strategy that deliver Exceptional Results68 % organic order increase 38.10%Reduced CPCLearn MoreCase StudyGolden Bee , a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosCase StudyGolden Bee , a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosLearn MoreCase StudyHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace Optimization . this Premium BabyCare 's aim to strengthen its brand visibility , increase revenue , and maintain profitability through efficient ad spend management.1 Crore INR Advertisement sale 8%tacoscase StudyHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace Optimization . this Premium BabyCare 's aim to strengthen its brand visibility , increase revenue , and maintain p ...
# {'source': 'https://www.regromedia.com/casestudy', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 4 ---
# Nexa - Free Agency Framer Template last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backooops!404 error : look like you have hit a dead end . do not worry , our web ninjas be on the case to bring you back to safety!Back to HomeBack to homelet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detail
# {'source': 'https://www.regromedia.com/404', 'title': 'Nexa - Free Agency Framer Template', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 5 ---
# Regro medium last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call BackPricing detailswelcome to RegroMedia , your premier Amazon advertisement service provider . we offer a range of advertising solution to help business maximize their sale potential on Amazon ’s platform . our pricing detail page provide you with information about our service , so you can make informed decision about which package be good for your business . our advertising solution be tailor to meet the specific need of each client . we understand that each business have unique goal and challenge , and we work closely with our client to create customize advertising campaign that drive result . our team of expert have year of experience in Amazon advertising , and we use the late technology and tool to optimize campaign for maximum roi . at RegroMedia , we offer a variety of package to fit any budget . whether you be a small business just start out on Amazon or a large enterprise look to expand your advertising effort , we have a package that ’ right for you . our package include a range of service , such as campaign strategy , creative design , ad placement , and performance tracking . in addition to our standard package , we also offer add - on service that can be customize to meet your specific need . these include competitor analysis , keyword research , product list optimization , and more . we work closely with our client to determine which add - on service will provide the great impact for their business . at RegroMedia , we believe in transparency when it come to pricing . while we do not provide specific pricing detail on our website , we be happy to discuss our package and price with you over the phone or via email . we be commit to provide our client with competitive pricing and value for their investment in our service . contact we today to learn more about our Amazon advertisement service and how we can help your business succeed on Amazon ’s platform . our team of expert be here to answer any question you may have and provide you with the information you need to make an informed decision about your advertising strategy . let'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detail
# {'source': 'https://www.regromedia.com/pricing-details', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 6 ---
# Regro medium last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackShipping policya an Amazon advertisement service provider , regromedia.com understand the importance of timely and efficient shipping . we strive to provide the good possible experience for our client by offer reliable shipping option and clear communication throughout the entire process . Shipping Times our standard shipping time be 2 - 5 business day for order within the United States . for international order , shipping time may vary depend on the destination country and shipping method select . we work with trust carrier to ensure that your package arrive in a timely manner . Shipping Rates we offer competitive shipping rate base on the size and weight of your order , as well as the shipping destination . shipping rate will be calculate and display at checkout . Order Processing Orders will typically be process within 1 - 2 business day of receive payment . if there be any delay or issue with your order , we will contact you via email or phone to provide an update . track your order once your order have be ship , we will provide you with a tracking number so you can monitor the progress of your shipment . you will receive an email notification with the tracking number and a link to the carrier ’s website . shipping delay while we strive to provide the fast shipping possible , there may be unforeseen delay that be out of our control . we be not responsible for any shipping delay cause by the carrier or any other factor outside of our control . if you experience any issue with your shipment , please contact we and we will do our good to resolve the issue . Shipping Address please ensure that you provide we with the correct shipping address at checkout . we be not responsible for any delay or issue cause by an incorrect shipping address . if you have any question or concern regard our shipping policy , please do not hesitate to contact we at as an Amazon advertisement service provider , regromedia.com understand the importance of timely and efficient shipping . we strive to provide the good possible experience for our client by offer reliable shipping option and clear communication throughout the entire process . Shipping Times our standard shipping time be 2 - 5 business day for order within the United States . for international order , shipping time may vary depend on the destination country and shipping method select . we work with trust carrier to ensure that your package arrive in a timely manner . Shipping Rates we offer competitive shipping rate base on the size and weight of your order , as well as the shipping destination . shipping rate will be calculate and display at checkout . Order Processing Orders will typically be process within 1 - 2 business day of receive payment . if there be any delay or issue with your order , we will contact you via email or phone to provide an update . track your order once your order have be ship , we will provide you with a tracking number so you can monitor the progress of your shipment . you will receive an email notification with the tracking number and a link to the carrier ’s website . shipping delay while we strive to provide the fast shipping possible , there may be unforeseen delay that be out of our control . we be not responsible for any shipping delay cause by the carrier or any other factor outside of our control . if you experience any issue with your shipment , please contact we and we will do our good to resolve the issue . Shipping Address please ensure that you provide we with the correct shipping address at checkout . we be not responsible for any delay or issue cause by an incorrect shipping address . if you have any question or concern regard our shipping policy , please do not hesitate to conta ...
# {'source': 'https://www.regromedia.com/shipping-policy', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 7 ---
# Regro medium last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackRefund & Cancellation PolicyRefund & Cancellation Policy for RegroMedia at RegroMedia , we be commit to provide our client with the good possible Amazon advertisement service . however , we understand that there may be circumstance where a client may need to cancel their order or request a refund . this policy outline our procedure for refund and cancellation . cancellation policy : if a client wish to cancel their order , they must notify we in writing as soon as possible . if the order have not yet be process , we will cancel the order and issue a full refund . if the order have already be process , we will work with the client to determine the good course of action , which may include issue a partial refund or offer credit for future service . Refund policy : we offer refund on a case - by - case basis . if a client be not satisfied with our service , they may request a refund within 30 day of the purchase date . refund will only be issue if we determine that the service provide be not as describe or if there be a technical issue that prevent we from deliver the service . to request a refund , client must contact we in writing and provide a detailed explanation of why they be request a refund . we will review the request and issue a refund if we determine that it be warrant . please note : we do not offer refund for any service that have already be complete or if the client have violate our term of service . we also do not offer refund if a digital course or training program be buy at a Discount or a limited time offer . contact information : if you have any question or concern regard our refund and cancellation policy , please contact we at Connect@regromedia.com we will be happy to assist you . let'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detail
# {'source': 'https://www.regromedia.com/refund-policy', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 8 ---
# Regro medium last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackPrivacy policyprivacy Policy for Regromedia.com at Regromedia , we be committed to protect the privacy of our website visitor and client . this Privacy Policy explain how we collect , use , and protect your personal information . collection of Information when you visit Regromedia.com , we may collect personal information that you provide to we , such as your name , email address , phone number , and company name . we may also collect non - personal information such as your IP address , browser type , and refer website . Use of Information we use the personal information we collect to provide you with our Amazon advertisement service and to communicate with you about your account . we may also use your information to send you promotional email about our service and update about our website . you may opt - out of receive these email at any time . sharing of Information we may share your personal information with third - party service provider who assist we in provide our service to you . these service provider be require to maintain the confidentiality and security of your personal information . we may also disclose your personal information if require by law or to protect our legal right . security of Information we take reasonable measure to protect the security of your personal information . however , no transmission of datum over the internet can be guarantee to be completely secure . therefore , we can not guarantee the security of any information you transmit to we , and you do so at your own risk . cooky Regromedia.com use cooky to enhance your browse experience and to provide our service . cooky be small text file that be store on your device . you may choose to disable cooky in your browser setting , but this may limit your ability to use certain feature of our website . link to other Websites our website may contain link to other website that be not own or control by Regromedia . we be not responsible for the privacy practice of these website and encourage you to review their privacy policy . update to Privacy Policy we reserve the right to update this Privacy Policy at any time . we will notify you of any significant change by post the update policy on our website . contact we if you have any question or concern about our Privacy Policy , please contact we at Connect@regromedia.com . let'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detail
# {'source': 'https://www.regromedia.com/privacy-policy', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 9 ---
# Regro medium last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackPrivacy policyprivacy Policy for Regromedia.com at Regromedia , we be committed to protect the privacy of our website visitor and client . this Privacy Policy explain how we collect , use , and protect your personal information . collection of Information when you visit Regromedia.com , we may collect personal information that you provide to we , such as your name , email address , phone number , and company name . we may also collect non - personal information such as your IP address , browser type , and refer website . Use of Information we use the personal information we collect to provide you with our Amazon advertisement service and to communicate with you about your account . we may also use your information to send you promotional email about our service and update about our website . you may opt - out of receive these email at any time . sharing of Information we may share your personal information with third - party service provider who assist we in provide our service to you . these service provider be require to maintain the confidentiality and security of your personal information . we may also disclose your personal information if require by law or to protect our legal right . security of Information we take reasonable measure to protect the security of your personal information . however , no transmission of datum over the internet can be guarantee to be completely secure . therefore , we can not guarantee the security of any information you transmit to we , and you do so at your own risk . cooky Regromedia.com use cooky to enhance your browse experience and to provide our service . cooky be small text file that be store on your device . you may choose to disable cooky in your browser setting , but this may limit your ability to use certain feature of our website . link to other Websites our website may contain link to other website that be not own or control by Regromedia . we be not responsible for the privacy practice of these website and encourage you to review their privacy policy . update to Privacy Policy we reserve the right to update this Privacy Policy at any time . we will notify you of any significant change by post the update policy on our website . contact we if you have any question or concern about our Privacy Policy , please contact we at Connect@regromedia.com . let'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detail
# {'source': 'https://www.regromedia.com/privacy-policy-2', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 10 ---
# Regro medium last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackTerms & conditionsterm and Conditions for regromedia.com : welcome to regromedia.com . these term and condition govern your use of our website . by use our website , you agree to these term and condition in full . if you disagree with these term and condition or any part of they , you must not use our website . Intellectual Property Rights the content on RegroMedia.com , include but not limit to text , graphic , logo , image , audio clip , and digital download , be the property of RegroMedia or its content supplier and be protect by international copyright law . you may not use any of this content without our express write permission . Use of the Website you may use regromedia.com for lawful purpose only . you may not use our website in any way that cause , or may cause , damage to the website or impairment of the availability or accessibility of the website , or in any way which be unlawful , illegal , fraudulent or harmful , or in connection with any unlawful , illegal , fraudulent or harmful purpose or activity . User - Generated Content RegroMedia.com may allow you to post content , such as comment or review , on our website . by post content on our website , you grant we a non - exclusive , transferable , sub - licensable , royalty - free , worldwide license to use , reproduce , modify , and display the content . you also warrant that any content you post on our website do not infringe any third - party right , include intellectual property right and privacy right . disclaimer of Liability RegroMedia.com provide the website on an " as be " and " as available " basis . we make no representation or warranty of any kind , express or imply , as to the operation of the website or the information , content , material , or product include on the website . we will not be liable for any damage of any kind arise from the use of the website , include , but not limit to , direct , indirect , incidental , punitive , and consequential damage . indemnification you agree to indemnify , defend , and hold harmless RegroMedia , its officer , director , employee , agent , licensor , and supplier from and against all loss , expense , damage , and cost , include reasonable attorney ’ fee , result from any violation of these term and condition or any activity relate to your account ( include negligent or wrongful conduct ) by you or any other person access the website use your account . govern Law these term and condition be govern by and construe in accordance with the law of [ insert jurisdiction ] . any dispute arise out of or in connection with these term and condition shall be subject to the exclusive jurisdiction of the court of [ insert jurisdiction ] . change to term and Conditions RegroMedia reserve the right to change these term and condition at any time without notice . by use our website , you agree to be bind by the current version of these term and condition . if you have any question or concern about these term and condition , please contact we at Connect@regromedia.comLet'sTalk!Last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycon ...
# {'source': 'https://www.regromedia.com/terms-and-conditions', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 11 ---
# regro medium our three Step ProcessHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonOur Three Step ProcessHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon the ChallengeWhen this skin CARE BRAND approach we , they be struggle with : rise ad cost ( CPC & ACOS).Heavy reliance on ad - drive sale instead of organic . difficulty in expand visibility in a crowded skincare market . our strategyto address these challenge , Regro Media implement a data - drive strategy : campaign restructuring → rebuild ad campaign for efficiency and scalability . high - Intent Keyword Targeting → ensure ad budget focus on proven converting keyword . CPC Optimization → closely monitor bid to reduce acquisition cost . balanced Growth → invest in organic ranking and conversion to maintain a healthy taco . result achieve in 4 Month1 . sale growthbrand ’s ad - drive sale grow from ₹ 30.3l in Feb to ₹ 39.0l in Apr , while total sale remain consistently strong between ₹ 70l – ₹ 85L per month . sale Trend ( ad vs total)sales Trend ( ad sale vs Total Sales ) this graph highlight the balance between ad - drive sale and overall revenue . ad sale ( orange line ) show how campaign contribute steadily between ₹ 30–39 lakh . total sale ( blue line ) remain in the range of ₹ 70–85 lakh , prove that organic contribution be grow alongside ad . Key Takeaway : even with ad spend optimization , total sale stay strong — show reduce dependency on ads.2 . ad EfficiencyCPC drop from ₹ 19.3 ( Mar ) → ₹ 16.8 ( Apr).ACOS improve from 37.6 % ( May ) → 32.3 % ( Apr ) CPC & ACOS Trend2.CPC & ACOS Trend this graph reflect advertising efficiency improvement over the month . CPC ( ₹ ) steadily drop from ₹ 19 + in March to ₹ 16–17 in later month , lower acquisition cost . ACOS ( % ) see a consistent decline , improve from ~38 % to ~32%.Key Takeaway : this Brand achieve cheap click and well return — a sign of smart ad targeting and campaign restructuring.3 . Engagement GrowthImpressions jump from 19.5 M ( Feb ) → 30.2 M ( mar).click scale to 75k+ per month . CTR improve by 30%+ . impression & Clicks Trend3 . impression & Clicks Trend this graph showcase visibility and engagement growth . impression ( blue bar ) scale from ~19 million to over 30 million , show high reach . click ( orange line ) cross 75 k per month , prove that audience engage more with the brand ’s adskey Takeaway : high CTR and click indicate strong relevance and consumer interest , translate into steady orders.4 . spend optimizationad Spend reduce from ₹ 13.7l ( May ) → ₹ 12.4l ( aug).tacos remain steady at ~16 % , ensure a scalable and profitable growth model . final ImpactIn just 4 month , this skin CARE BRAND achieved:27 % low CPC5.5 percentage point ACOS improvement24 % more click ( higher engagement)stable 16 % TACOSSustained sale while spend less on adsConclusionBy partnering with Regro Media , a skin CARE BRAND learn that growth on Amazon be not just about spend more — it ’ about spend smarter . with reduced CPC , improve ACOS , and a healthy ad - to - organic balance , this skin CARE BRAND build a foundation for long - term growth in a highly competitive category . the ChallengeWhen this skin CARE BRAND approach we , they be struggle with : rise ad cost ( CPC & ACOS).Heavy reliance on ad - drive sale instead of organic . difficulty in expand visibility in a crowded skincare market . our strategyto address these challenge , Regro Media implement a data - drive strategy : campaign restructuring → rebuild ad campaign for efficiency and scalability . high - Intent Keyword Targeting → ensure ad budget focus on proven converting keyword . CPC Optimization → closely monitor bid to reduce acquisition cost . balanced Growth → invest in organic ranking and conversion to maintain a healthy taco . result achieve in 4 Month1 . sale growthbrand ’s ad -  ...
# {'source': 'https://www.regromedia.com/case-studies/skin-care-brand', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 12 ---
# ...
# {'source': 'https://www.regromedia.com/case-studies/scaled-this-baby-care-brand-to-new-hights', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 17 ---
# regro medium our three Step ProcessThis Body Warmer Brand see sale Growth with Lowe Task . our three Step ProcessThis Body Warmer Brand see sale Growth with Lowe Task . how Warmee Bee achieve sale Growth while lower tacos below 10 % on AmazonExecutive Summary : a Data - back Growth Strategy that deliver Exceptional ResultsWarmee Bee , a new brand in the body warm category , partner with our Amazon marketing agency to break through a highly competitive market . with a strategic mix of ad campaign restructuring , precise keyword targeting , and seo optimization , Warmee Bee achieve : taco reduce to 9.8 % from a previous 14 % CPC lower from 38.01 % organic order increase by 68%looke to scale your brand profitably on Amazon ? get in touch with we today for a free strategy session ! Data Screenshot suggestion : how Warmee Bee achieve sale Growth while lower tacos below 10 % on AmazonExecutive Summary : a Data - back Growth Strategy that deliver Exceptional ResultsWarmee Bee , a new brand in the body warm category , partner with our Amazon marketing agency to break through a highly competitive market . with a strategic mix of ad campaign restructuring , precise keyword targeting , and seo optimization , Warmee Bee achieve : taco reduce to 9.8 % from a previous 14 % CPC lower from 38.01 % organic order increase by 68%looke to scale your brand profitably on Amazon ? get in touch with we today for a free strategy session ! Data Screenshot suggestion : Client overview : Warmee Bee ’s Business Goals and VisionWarmee Bee aim to : enhance brand awareness and reach a broad audience in the body warm category . scale revenue while maintain profitability , ensure taco remain under 10 % . establish a foothold in a competitive market , where low - cost traditional warmer dominate . CTA : want to build a sustainable , profitable business on Amazon ? let ’s talk about your growth strategy ! Data Screenshot : before - and - after Amazon storefront traffic report to highlight visibility improvement . challenge : overcome market Barriers to SuccessWarmee Bee face three major challenge in scale its brand on Amazon : low brand awareness – compete against well - establish traditional body warm brand . balance taco with Sales Growth – increase sale while maintain a lean ad budget . high CPC in a saturated market – compete in a high - bid niche , where CPC exceed ₹ 21.facing high ad cost and intense competition ? our team can help optimize your Amazon strategy for maximum profitability . Data Screenshot : advertising cost breakdown illustrate CPC trend before optimization . solution framework : strategy design for impactwe implement a multi - tiere strategy to drive growth and enhance Warmee Bee ’s profitability : 1 . campaign restructuring for Efficiency – shift budget toward high - perform keyword , reduce CPC from ₹ 21 to ₹ 13 . 2 . Broad & Precise Keyword Targeting – increase organic ranking and discoverability , lead to a 68 % surge in organic order . 3 . A / B Testing & Negative Keyword Optimization – eliminated non - performing keyword , cut waste ad spend by 35 % . 4 . dayparte Strategy for Better Ad Spend Management – adjust ad budget base on hourly sale trend , improve conversion rate by 22%.want high sale and low ad cost ? let ’s develop a customize Amazon strategy for your brand ! Data Screenshot : result deliver : a measurable Boost in Sales & Efficiency Sales Milestone : surpass the revenue in a BAU month , the high in brand history . reduced CPC : drop CPC 38.10 % , cut ad cost significantly . optimize taco : achieve a tacos of 9.8 % , down from 14 % , ensure well profitability . Improved Organic Ranking : increase organic order by 68 % , reduce dependency on ad . want to achieve similar success with low ad spend ? contact we now for a personalized growth strategy ! Data Screenshot : Data visualization : Warmee Bee ’s Growth in Numbers CPC reduce from ₹ 21 to ₹ 13 , save ad cost tacos reduce from 14 % to 9.8 % , improve profitability 68 % i ...
# {'source': 'https://www.regromedia.com/case-studies/this-body-warmer-brand', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 18 ---
# regro medium our three Step ProcessGolden Bee , a brand navigate a highly competitive marketOur three Step ProcessGolden Bee , a brand navigate a highly competitive marketGolden Bee ’s Amazon Success Story : scale 4x in sale while maintain taco under 10%executive Summary : a Growth - drive Amazon Strategy that DeliveredGolden Bee , a brand navigate a highly competitive market , partner with our Amazon marketing agency to drive high sale while maintain a lean taco ( Total Advertising Cost of sale ) under 10 % . through strategic ad spend optimization , precise keyword targeting , and improve conversion rate , we achieve a revenue milestone of ₹ XX,00,000 in a BAU ( business - as - usual ) month — a significant leap from past performance . want to scale your brand on Amazon with data - back strategy ? let ’s talk!Golden Bee ’s Amazon Success Story : scale 4x in sale while maintain taco under 10%executive Summary : a Growth - drive Amazon Strategy that DeliveredGolden Bee , a brand navigate a highly competitive market , partner with our Amazon marketing agency to drive high sale while maintain a lean taco ( Total Advertising Cost of sale ) under 10 % . through strategic ad spend optimization , precise keyword targeting , and improve conversion rate , we achieve a revenue milestone of ₹ XX,00,000 in a BAU ( business - as - usual ) month — a significant leap from past performance . want to scale your brand on Amazon with data - back strategy ? let ’s talk!Client overview : Golden Bee ’s Business Goals and VisionGolden Bee aim to increase sale without compromise profitability , ensure taco remain below 10 % . compete in a price - sensitive market , the brand seek to enhance product visibility , outperform low - cost competitor , and maximize ad efficiency . ready to position your brand for long - term growth on Amazon ? let ’s craft your win strategy today ! Data Screenshot : show a before - and - after taco performance report to highlight improvement . challenge : navigate a Competitive MarketplaceDespite its strong product line , Golden Bee face major obstacle that impact its growth : balance sale Growth with TACoS efficiency – increase revenue while ensure ad spend remain under control . compete with lower - price Brands – navigate a saturate market where competitor slash price to dominate ranking . optimize ad performance – lower CPC ( cost per Click ) while ensure ad reach high - intent customer . struggle with high taco and competitive pricing pressure ? our Amazon expert can help you gain a competitive edge . Data Screenshot : include an advertising cost breakdown show CPC trend before and after optimization . solution framework : strategy design for impactto help Golden Bee achieve its ambitious goal , we deploy a highly data - drive strategy that include : 1 . Smart Relevance - base Targeting – Refining keyword target to reduce waste spend and enhance CVR ( Conversion Rate ) . 2 . competitive safeguarding – update detail page and implement negative keyword to shield listing from competitor ad . 3 . CPC Optimization – cut CPC from ₹ 20-₹24 down to ₹ 12-₹14 while improve ad efficiency . ⏳ 4 . Hourly Budget Allocation – dayparte ad spend base on peak performance hour to ensure maximum ROI.Get a customize Amazon growth strategy to maximize your brand ’s potential . schedule a free audit now!result deliver : Measurable Business OutcomesBy consistently refining advertising and budget strategy , Golden Bee achieve tangible success in a short timeframe : Sales Milestone : hit ₹ XX,00,000 in a BAU month — surpass all previous benchmark . CPC reduction : bring CPC down to ₹ 12-₹14 , significantly lower ad cost . TACoS Optimization : maintain a sub-10 % taco for consecutive month , ensure long - term profitability . want to see similar success for your brand ? contact we for a free consultation today!Data Visualization : Key Insights in Numbers ₹ XXL Sales Milestone achieve in one BAU month CPC reduce by 40 % , taco stabilize below 10 ...
# {'source': 'https://www.regromedia.com/case-studies/golden-bee', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}
#
# --- DOCUMENT 19 ---
# regro medium our three Step ProcessHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace Optimization . our three Step ProcessHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace Optimization . how this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace OptimizationExecutive Summary : drive E - Commerce Success with a Data - back ApproachThis Premium BabyCare 's , a brand commit to deliver high - quality product , partner with our Amazon marketing agency to enhance its marketplace performance . by implement a highly targeted advertising and content strategy , we transform their presence on Amazon , lead to a remarkable sale surge from ₹ 80 lakh to ₹ 1 crore , while simultaneously optimize Advertising Cost of Sale ( ACOS ) to 12%.How this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace OptimizationExecutive Summary : drive E - Commerce Success with a Data - back ApproachThis Premium BabyCare 's , a brand commit to deliver high - quality product , partner with our Amazon marketing agency to enhance its marketplace performance . by implement a highly targeted advertising and content strategy , we transform their presence on Amazon , lead to a remarkable sale surge from ₹ 80 lakh to ₹ 1 crore , while simultaneously optimize Advertising Cost of Sale ( ACOS ) to 12%.client overview : this Premium BabyCare 's ’s Business Goals and VisionThis Premium BabyCare 's aim to strengthen its brand visibility , increase revenue , and maintain profitability through efficient ad spend management . compete in a highly saturate market , the brand seek scalable growth strategy to establish a strong foothold in its niche on Amazon . want to take your brand from good to great on Amazon ? let ’s discuss how we can make it happen for you . Data Screenshot : challenge : overcome barrier to Marketplace SuccessWhile this Premium BabyCare 's have a strong product lineup , it face key challenge that hinder its full potential : boost sale and TACOS Efficiency – struggle with high Total Advertising Cost of Sale ( TACOS ) and inconsistent sale performance . New Product Performance Enhancement – compete in a saturate market with high cpc ( cost per Click ) and dominant big - brand competitor . optimize ad spend for Maximum ROI – ensure each ad dollar spend contribute to high conversion and brand growth . face similar marketplace challenge ? our data - drive Amazon strategy can help you turn obstacle into opportunity . solution framework : strategy design for ImpactOur team develop a multi - layered growth plan tailor to this Premium BabyCare 's ’s objective : 1 . Hourly Ad Budget Optimization – analyze hourly sale trend to allocate budget more efficiently during peak buying hour . 2 . target Keyword Expansion – enhance ad visibility on relevant keyword to capture high - intent shopper . 3 . CPC & Category Reallocation – reduce ad spend in non - converting area and shift focus to high - perform category . 4 . Voice Share Domination – improve brand recall and sale by increase ad share of voice on Amazon ’s top search result . discover how a strategic campaign optimization approach can drive your brand ’s success . contact we today ! Data Screenshot : result deliver : how this Premium BabyCare 's achieve Scalable GrowthWith a structured advertising and optimization strategy , this Premium BabyCare 's see tangible result within a short timeframe : sale growth : scale from ₹ 80 lakh to ₹ 1 crore in revenue . advertising Efficiency : improve ACOS to 12 % , maximize profit margin . optimized budgeting : reduced spend on underperform ad while enhance ROI on high - convert product . ready to witness game - change result for your Amazon store ? let us start build your custom strategy today . Data Visualization : insight back by NumbersVisualizing success be just as important as achieve it . here ’ a breakdown of This Premium BabyCare ...
# {'source': 'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}

# %%
# Split into smaller chunks for llm to understand 
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
regro_media_data_chunks = text_splitter.split_documents(regro_media_cleaned_data)
regro_media_data_chunks
# Out:
# [Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='Regro medium last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call Back#1 Amazon ADS Agency in india200 + 5 Star ReviewsTheBestAwardedAmazonAdsAgency . experience our award - win , holistic approach to maximize visibility , conversion , and ROI for your brandschedule a CallSchedule a CallBest AmazonAds Agency play video know about US agenceeserviceswhat we be offeringserviceswhat we be offeringschedule a CallAdvertising ManagementRegro Media have be award as the Best perform agency for Q1,Q2 & Q4 by Amazon itself . our Team of Experts have be certify to handle any Adverse Problems and solve it weather it be Amazon Ads or DSP learn MoreAdvertising ManagementRegro Media have be award as the Best perform agency for Q1,Q2 & Q4 by Amazon itself . our Team of Experts have be certify to handle'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='it weather it be Amazon Ads or DSP learn MoreAdvertising ManagementRegro Media have be award as the Best perform agency for Q1,Q2 & Q4 by Amazon itself . our Team of Experts have be certify to handle any Adverse Problems and solve it weather it be Amazon Ads or DSP Learn MoreImages & Creatives we can help , whether its a+ content list image or Premium A+ Content , Brand Story , Brand Store or Video . our expert be experience to generate high converting creative for your brand . Learn MoreImages & Creatives we can help , whether its a+ content list image or Premium A+ Content , Brand Story , Brand Store or Video . our expert be experience to generate high converting creative for your brand . Learn MoreTraining & CoachingLearn the top strategy we use ForManaging over $ 150 + million in revenue . join the top 10 % of Amazon Sellers make profit with great ROI & Conversion Rate with our Proven design sop’s . Learn MoreTraining & CoachingLearn the top strategy we use ForManaging over $ 150'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content=". join the top 10 % of Amazon Sellers make profit with great ROI & Conversion Rate with our Proven design sop’s . Learn MoreTraining & CoachingLearn the top strategy we use ForManaging over $ 150 + million in revenue . join the top 10 % of Amazon Sellers make profit with great ROI & Conversion Rate with our Proven design sop’s . learn MoreSEO & Listing optimizationWe understand the importance of seo in maximize your Amazon list 's potential and help secure the high Ranking Juice in your niche with our advanced Help!Learn MoreSEO & Listing optimizationWe understand the importance of seo in maximize your Amazon list 's potential and help secure the high Ranking Juice in your niche with our advanced help!learn moreserviceswhat we be offeringschedule a CallAdvertising ManagementRegro Media have be award as the Best perform agency for Q1,Q2 & Q4 by Amazon itself . our Team of Experts have be certify to handle any Adverse Problems and solve it weather it be Amazon Ads or DSP Learn"),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="Media have be award as the Best perform agency for Q1,Q2 & Q4 by Amazon itself . our Team of Experts have be certify to handle any Adverse Problems and solve it weather it be Amazon Ads or DSP Learn MoreImages & Creatives we can help , whether its a+ content list image or Premium A+ Content , Brand Story , Brand Store or Video . our expert be experience to generate high converting creative for your brand . Learn MoreTraining & CoachingLearn the top strategy we use ForManaging over $ 150 + million in revenue . join the top 10 % of Amazon Sellers make profit with great ROI & Conversion Rate with our Proven design sop’s . learn MoreSEO & Listing optimizationWe understand the importance of seo in maximize your Amazon list 's potential and help secure the high Ranking Juice in your niche with our advanced help!learn MoreBrands CollaboraationsBrands that trust usbrand CollaboraationsBrands that trust us8+Years of experience200+successful projects180+happy clients35+member TeamProven Track"),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='our advanced help!learn MoreBrands CollaboraationsBrands that trust usbrand CollaboraationsBrands that trust us8+Years of experience200+successful projects180+happy clients35+member TeamProven Track RecordWe have build a reputation as a trusted and reliable partner in achieve business success . proven Track RecordWe have build a reputation as a trusted and reliable partner in achieve business success . tailor solutionswe offer personalize solution tailor to your specific goal , audience , and industry . tailor solutionswe offer personalize solution tailor to your specific goal , audience , and industry . Client - Centric FocusYour success be our priority . we prioritize understand your business goal . Client - Centric FocusYour success be our priority . we prioritize understand your business goal . Continuous InnovationDedicated SupportPositive Client ExperiencesCommitment to excellence8+year of experience200+successful projects180+happy clients35+member TeamProven Track RecordWe have'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='goal . Continuous InnovationDedicated SupportPositive Client ExperiencesCommitment to excellence8+year of experience200+successful projects180+happy clients35+member TeamProven Track RecordWe have build a reputation as a trusted and reliable partner in achieve business success . tailor solutionswe offer personalize solution tailor to your specific goal , audience , and industry . Client - Centric FocusYour success be our priority . we prioritize understand your business goal . Continuous InnovationDedicated SupportPositive Client ExperiencesCommitment to ExcellenceOur client that feature in Shank TankWe help these brand with Amazon ad and DSPOur client that feature in Shank TankOur client that feature in Shank TankOur client that feature in Shank TankWe help these brand with Amazon ad and DSPWe help these brand with Amazon ad and DSPWe help these brand with Amazon ad and DSPLeveraging Talent + Tech to scale your brand and capture audience effectively , let you focus on what matter .'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='DSPWe help these brand with Amazon ad and DSPWe help these brand with Amazon ad and DSPLeveraging Talent + Tech to scale your brand and capture audience effectively , let you focus on what matter . leverage Talent + Tech to scale your brand and capture audience effectively , let you focus on what matters.worke together , grow together , and rid the momentum to success . leverage Talent + Tech to scale your brand and capture audience effectively , let you focus on what matter . we believe in combine innovative design , sustainable practice , and exceptional craftsmanship to bring your vision to life . WorksCase StudiesCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%TACOSCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%tacoslearn MoreCase'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%tacoslearn MoreCase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % tacoscase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % TACOSLearn MoreCase StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%case StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%learn MoreCase studyfame rugs on"),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%learn MoreCase studyfame rugs on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,case studyfame RUGS on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,learn MoreView all ProjectsWorksCase StudiesCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="K ↓47%acos from 41.6 % → 22%,learn MoreView all ProjectsWorksCase StudiesCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%tacoslearn MoreCase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % TACOSLearn MoreCase StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%learn MoreCase studyfame rugs on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,learn"),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,learn MoreView all projectstestimonialpartnere with REGRO MEDIA have be one of the good decision we have make for grow our business on Amazon . their team bring deep expertise in Amazon advertising , list optimization , and marketplace strategy , help we stand out in an increasingly competitive space . they handle everything - from optimize our product listing with high - convert copy and backend keyword , to manage advanced Sponsored Ads and DSP campaign . within a short time , we see significant improvement in product visibility , low ACOS , and a steady increase in conversion and overall sale . what really set REGRO MEDIA apart be their commitment to result and communication . they provide clear performance report , regular strategy update , and be always available for feedback and campaign'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='what really set REGRO MEDIA apart be their commitment to result and communication . they provide clear performance report , regular strategy update , and be always available for feedback and campaign adjustment . it feel like work with a true extension of our in - house team . if you be an Amazon seller look to scale your store and drive measurable growth , REGRO MEDIA be the agency to trustreliable , Results - drive Amazon MarketingOrthopedic Pillow brandMay 29 , 2025regro medium team be a well experienced team that be capable of manage your PPC account . go AheadTripole GearsMay 17 , 2025great service be not measure when everything go right- it be truly tete when thing go wrong . I be happy to say thet when ever thing go wrong regro medium have step up and work hard to make thing right . we have be work with they for a long time now and I genuinely recomment thrir service to anyone look for a reliable and committed partner . Great ServiceHydermay 15 , 2025Rohan KhandujaOwner ,'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='. we have be work with they for a long time now and I genuinely recomment thrir service to anyone look for a reliable and committed partner . Great ServiceHydermay 15 , 2025Rohan KhandujaOwner , Tripole GearsTanay GalaOwner , Anupam StationarySchedule a callreviewspartnere with REGRO MEDIA have be one of the good decision we have make for grow our business on Amazon . their team bring deep expertise in Amazon advertising , list optimization , and marketplace strategy , help we stand out in an increasingly competitive space . they handle everything - from optimize our product listing with high - convert copy and backend keyword , to manage advanced Sponsored Ads and DSP campaign . within a short time , we see significant improvement in product visibility , low ACOS , and a steady increase in conversion and overall sale . what really set REGRO MEDIA apart be their commitment to result and communication . they provide clear performance report , regular strategy update , and be always'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='in conversion and overall sale . what really set REGRO MEDIA apart be their commitment to result and communication . they provide clear performance report , regular strategy update , and be always available for feedback and campaign adjustment . it feel like work with a true extension of our in - house team . if you be an Amazon seller look to scale your store and drive measurable growth , REGRO MEDIA be the agency to trustreliable , Results - drive Amazon MarketingOrthopedic Pillow brandMay 29 , 2025regro medium team be a well experienced team that be capable of manage your PPC account . go AheadTripole GearsMay 17 , 2025great service be not measure when everything go right- it be truly tete when thing go wrong . I be happy to say thet when ever thing go wrong regro medium have step up and work hard to make thing right . we have be work with they for a long time now and I genuinely recomment thrir service to anyone look for a reliable and committed partner . Great ServiceHydermay 15'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='work hard to make thing right . we have be work with they for a long time now and I genuinely recomment thrir service to anyone look for a reliable and committed partner . Great ServiceHydermay 15 , 2025Rohan KhandujaOwner , Tripole GearsTanay GalaOwner , Anupam StationarySchedule a CallWhy UsOur specialitieswe utilize advanced technique for enhanced visibility and optimize ad spend . through our marketing stream and tracking capability , we ensure that every dollar spend deliver a meaningful impact , drive measurable result for your brand . why UsOur specialitieswe utilize advanced technique for enhanced visibility and optimize ad spend . through our marketing stream and tracking capability , we ensure that every dollar spend deliver a meaningful impact , drive measurable result for your brand . client choose to stay with we over the long run due to the exceptional result we deliver and the strong relationship we build . client choose to stay with we over the long run due to the'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='your brand . client choose to stay with we over the long run due to the exceptional result we deliver and the strong relationship we build . client choose to stay with we over the long run due to the exceptional result we deliver and the strong relationship we build.$200m$200mrevenue generatedwe help generate $ 200 m revenue for our client around the globeQualityPersonalizationReliabilityCollaborationInnovationCustomer FocusLong - Term RelationshipsPositive experiencetrustworthinesspassioncustomer SupportEnhanced Brand Visibility80%Advertisig plan include DSP for a client , recurite in a significant increase in brand visibility and recognition . as a result , the client experience a 80 % increase in Amazon traffic wthin six monthswhy UsOur specialitieswe utilize advanced technique for enhanced visibility and optimize ad spend . through our marketing stream and tracking capability , we ensure that every dollar spend deliver a meaningful impact , drive measurable result for your brand .'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='visibility and optimize ad spend . through our marketing stream and tracking capability , we ensure that every dollar spend deliver a meaningful impact , drive measurable result for your brand . client choose to stay with we over the long run due to the exceptional result we deliver and the strong relationship we build.$200mrevenue generatedwe help generate $ 200 m revenue for our client around the globeQualityPersonalizationReliabilityCollaborationInnovationCustomer FocusLong - Term RelationshipsPositive experiencetrustworthinesspassioncustomer SupportEnhanced Brand Visibility80%Advertisig plan include DSP for a client , recurite in a significant increase in brand visibility and recognition . as a result , the client experience a 80 % increase in Amazon traffic wthin six monthsour TeamOur Team MembersOur TeamOur Team MembersSAMMY AKTHARCO - FOUNDERSANDEEP SAJWANC0 - FOUNDERTAPAN KARANCMO cum HRSHILPA ARORAPPC SPECIALISTDEEPAK KUMARMISBHARAT GAVHANEPPC SPECIALISTMD . AHMADPPC'),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="TeamOur Team MembersOur TeamOur Team MembersSAMMY AKTHARCO - FOUNDERSANDEEP SAJWANC0 - FOUNDERTAPAN KARANCMO cum HRSHILPA ARORAPPC SPECIALISTDEEPAK KUMARMISBHARAT GAVHANEPPC SPECIALISTMD . AHMADPPC SPECIALISTMUHAMMAD HAMIDPPC SPECIALISTTanishq RathorePPC SPECIALISTAshwani PatelCXOHarsh Dev SharmaAPPOINTMENT SETTERSnehal Yogesh AhirraoMARKETINGPrajakta KapoteAPPOINTMENT SETTERRAZI CHAUDHARYSEO SPECIALISTVinay CHAUHANPPC SPECIALISTDipanjan DasPPC SPECIALISTKomal sharmamarketingmarhama KIRMANIDATA ANALYSTSoniya JoshiMARKETINGPeddiReddy VenkatlakshmiDATA ANALYSTPeddireddi srinivasAPPOINTMENT SETTERSagar BhagchandaniPPC LEADMamta sharmaDATA ANALYSTHafeezur RahmanPR HEADChowdhury AminurzamanVIDEO editorlet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages &"),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content=") +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri"),
#  Document(metadata={'source': 'https://www.regromedia.com/', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detail"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="Regro medium last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackCheck our Works with Real ResultsCheck our Works with Real ResultsCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%TACOSCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%tacoslearn MoreCase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % tacoscase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % tacoscase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % TACOSLearn MoreCase StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%case StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%learn MoreCase studyfame rugs on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="$ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,case studyfame RUGS on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,learn MoreCase StudyTripole 's Amazon Success Story : from Challenges to Market DominationHow it manage Low CTR , High ACOS in such competitive market .33.33%Sales growth in 5 Months67 % increase in OrdervolumeCase StudyTripole 's Amazon Success Story : from Challenges to Market DominationHow it manage Low CTR , High ACOS in such competitive market .33.33%Sales growth in 5 Months67 % increase in OrdervolumeLearn MoreCase StudyScaled this"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='Story : from Challenges to Market DominationHow it manage Low CTR , High ACOS in such competitive market .33.33%Sales growth in 5 Months67 % increase in OrdervolumeLearn MoreCase StudyScaled this Baby Care Brand to new hight . from Challenges to Market Place domination.123%growth in Revenue 30%roas ImprovementCase StudyScaled this Baby Care Brand to new hight . from Challenges to Market Place domination.123%growth in Revenue 30%roas ImprovementLearn MoreCase studythis Body Warmer Brand see sale Growth with Lowe Task . a Data - back Growth Strategy that deliver Exceptional Results68 % organic order increase 38.10%reduced CPCCase studythis Body Warmer Brand see sale Growth with Lowe Task . a Data - back Growth Strategy that deliver Exceptional Results68 % organic order increase 38.10%Reduced CPCLearn MoreCase StudyGolden Bee , a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosCase StudyGolden Bee , a brand navigate a highly'),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="CPCLearn MoreCase StudyGolden Bee , a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosCase StudyGolden Bee , a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosLearn MoreCase StudyHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace Optimization . this Premium BabyCare 's aim to strengthen its brand visibility , increase revenue , and maintain profitability through efficient ad spend management.1 Crore INR Advertisement sale 8%tacoscase StudyHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace Optimization . this Premium BabyCare 's aim to strengthen its brand visibility , increase revenue , and maintain profitability through efficient ad spend management.1 Crore INR Advertisement Sales 8%tacoslearn MoreCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="profitability through efficient ad spend management.1 Crore INR Advertisement Sales 8%tacoslearn MoreCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%tacoslearn MoreCase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % TACOSLearn MoreCase StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%learn MoreCase studyfame rugs on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="$ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,learn MoreCase StudyTripole 's Amazon Success Story : from Challenges to Market DominationHow it manage Low CTR , High ACOS in such competitive market .33.33%Sales growth in 5 Months67 % increase in OrdervolumeLearn MoreCase StudyScaled this Baby Care Brand to new hight . from Challenges to Market Place domination.123%growth in Revenue 30%roas ImprovementLearn MoreCase studythis Body Warmer Brand see sale Growth with Lowe Task . a Data - back Growth Strategy that deliver Exceptional Results68 % organic order increase 38.10%Reduced CPCLearn MoreCase StudyGolden Bee , a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosLearn MoreCase StudyHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content=", a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosLearn MoreCase StudyHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace Optimization . this Premium BabyCare 's aim to strengthen its brand visibility , increase revenue , and maintain profitability through efficient ad spend management.1 Crore INR Advertisement Sales 8%tacoslearn morelet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detail'),
#  Document(metadata={'source': 'https://www.regromedia.com/casestudy', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="Regro medium last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackCheck our Works with Real ResultsCheck our Works with Real ResultsCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%TACOSCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%tacoslearn MoreCase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % tacoscase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category"),
#  Document(metadata={'source': 'https://www.regromedia.com/casestudy', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % tacoscase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % TACOSLearn MoreCase StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%case StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%learn MoreCase studyfame rugs on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K"),
#  Document(metadata={'source': 'https://www.regromedia.com/casestudy', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="$ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,case studyfame RUGS on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,learn MoreCase StudyTripole 's Amazon Success Story : from Challenges to Market DominationHow it manage Low CTR , High ACOS in such competitive market .33.33%Sales growth in 5 Months67 % increase in OrdervolumeCase StudyTripole 's Amazon Success Story : from Challenges to Market DominationHow it manage Low CTR , High ACOS in such competitive market .33.33%Sales growth in 5 Months67 % increase in OrdervolumeLearn MoreCase StudyScaled this"),
#  Document(metadata={'source': 'https://www.regromedia.com/casestudy', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content='Story : from Challenges to Market DominationHow it manage Low CTR , High ACOS in such competitive market .33.33%Sales growth in 5 Months67 % increase in OrdervolumeLearn MoreCase StudyScaled this Baby Care Brand to new hight . from Challenges to Market Place domination.123%growth in Revenue 30%roas ImprovementCase StudyScaled this Baby Care Brand to new hight . from Challenges to Market Place domination.123%growth in Revenue 30%roas ImprovementLearn MoreCase studythis Body Warmer Brand see sale Growth with Lowe Task . a Data - back Growth Strategy that deliver Exceptional Results68 % organic order increase 38.10%reduced CPCCase studythis Body Warmer Brand see sale Growth with Lowe Task . a Data - back Growth Strategy that deliver Exceptional Results68 % organic order increase 38.10%Reduced CPCLearn MoreCase StudyGolden Bee , a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosCase StudyGolden Bee , a brand navigate a highly'),
#  Document(metadata={'source': 'https://www.regromedia.com/casestudy', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="CPCLearn MoreCase StudyGolden Bee , a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosCase StudyGolden Bee , a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosLearn MoreCase StudyHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace Optimization . this Premium BabyCare 's aim to strengthen its brand visibility , increase revenue , and maintain profitability through efficient ad spend management.1 Crore INR Advertisement sale 8%tacoscase StudyHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace Optimization . this Premium BabyCare 's aim to strengthen its brand visibility , increase revenue , and maintain profitability through efficient ad spend management.1 Crore INR Advertisement Sales 8%tacoslearn MoreCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin"),
#  Document(metadata={'source': 'https://www.regromedia.com/casestudy', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="profitability through efficient ad spend management.1 Crore INR Advertisement Sales 8%tacoslearn MoreCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%tacoslearn MoreCase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % TACOSLearn MoreCase StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%learn MoreCase studyfame rugs on Amazon.com ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K"),
#  Document(metadata={'source': 'https://www.regromedia.com/casestudy', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="$ 380.8 k ( ↑81%)A Premium Home Decor Brand on Amazon.com : ACOS drop from 41.6 % to 22 % while total sale surge from $ 210 k → $ 380.8 k ( ↑81%)↑81%Total Monthly sale surge from $ 210 k → $ 380.8 K ↓47%acos from 41.6 % → 22%,learn MoreCase StudyTripole 's Amazon Success Story : from Challenges to Market DominationHow it manage Low CTR , High ACOS in such competitive market .33.33%Sales growth in 5 Months67 % increase in OrdervolumeLearn MoreCase StudyScaled this Baby Care Brand to new hight . from Challenges to Market Place domination.123%growth in Revenue 30%roas ImprovementLearn MoreCase studythis Body Warmer Brand see sale Growth with Lowe Task . a Data - back Growth Strategy that deliver Exceptional Results68 % organic order increase 38.10%Reduced CPCLearn MoreCase StudyGolden Bee , a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosLearn MoreCase StudyHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with"),
#  Document(metadata={'source': 'https://www.regromedia.com/casestudy', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content=", a brand navigate a highly competitive markethow it scale 4x in sale while maintain taco under 10%<10 % TacosLearn MoreCase StudyHow this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace Optimization . this Premium BabyCare 's aim to strengthen its brand visibility , increase revenue , and maintain profitability through efficient ad spend management.1 Crore INR Advertisement Sales 8%tacoslearn morelet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA"),
# ...
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content=": enhance product listing – seo - drive description , engage visual , and keyword - rich title . customer - Centric Approach – optimize Q&A section and review to build credibility . A+ Content & Storefront Optimization – increase engagement through premium content strategy . your content be your brand ’s voice on Amazon . let ’s optimize it for high visibility and conversion . conclusion : this Premium BabyCare 's ’s growth be just the BeginningThis Premium BabyCare 's ’s success story be proof that with the right strategy , data - drive decision - making , and continuous optimization , brand can achieve scalable growth on Amazon . if you ’re look to transform your e - commerce business , let ’s create a custom strategy tailor to your goal . contact we today!How this Premium BabyCare 's Scaled to ₹ 1 Crore sale on Amazon with Strategic Marketplace OptimizationExecutive Summary : drive E - Commerce Success with a Data - back ApproachThis Premium BabyCare 's , a brand commit to deliver"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="to ₹ 1 Crore sale on Amazon with Strategic Marketplace OptimizationExecutive Summary : drive E - Commerce Success with a Data - back ApproachThis Premium BabyCare 's , a brand commit to deliver high - quality product , partner with our Amazon marketing agency to enhance its marketplace performance . by implement a highly targeted advertising and content strategy , we transform their presence on Amazon , lead to a remarkable sale surge from ₹ 80 lakh to ₹ 1 crore , while simultaneously optimize Advertising Cost of Sale ( ACOS ) to 12%.client overview : this Premium BabyCare 's ’s Business Goals and VisionThis Premium BabyCare 's aim to strengthen its brand visibility , increase revenue , and maintain profitability through efficient ad spend management . compete in a highly saturate market , the brand seek scalable growth strategy to establish a strong foothold in its niche on Amazon . want to take your brand from good to great on Amazon ? let ’s discuss how we can make it happen for"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content=", the brand seek scalable growth strategy to establish a strong foothold in its niche on Amazon . want to take your brand from good to great on Amazon ? let ’s discuss how we can make it happen for you . Data Screenshot : challenge : overcome barrier to Marketplace SuccessWhile this Premium BabyCare 's have a strong product lineup , it face key challenge that hinder its full potential : boost sale and TACOS Efficiency – struggle with high Total Advertising Cost of Sale ( TACOS ) and inconsistent sale performance . New Product Performance Enhancement – compete in a saturate market with high cpc ( cost per Click ) and dominant big - brand competitor . optimize ad spend for Maximum ROI – ensure each ad dollar spend contribute to high conversion and brand growth . face similar marketplace challenge ? our data - drive Amazon strategy can help you turn obstacle into opportunity . solution framework : strategy design for ImpactOur team develop a multi - layered growth plan tailor to this"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="challenge ? our data - drive Amazon strategy can help you turn obstacle into opportunity . solution framework : strategy design for ImpactOur team develop a multi - layered growth plan tailor to this Premium BabyCare 's ’s objective : 1 . Hourly Ad Budget Optimization – analyze hourly sale trend to allocate budget more efficiently during peak buying hour . 2 . target Keyword Expansion – enhance ad visibility on relevant keyword to capture high - intent shopper . 3 . CPC & Category Reallocation – reduce ad spend in non - converting area and shift focus to high - perform category . 4 . Voice Share Domination – improve brand recall and sale by increase ad share of voice on Amazon ’s top search result . discover how a strategic campaign optimization approach can drive your brand ’s success . contact we today ! Data Screenshot : result deliver : how this Premium BabyCare 's achieve Scalable GrowthWith a structured advertising and optimization strategy , this Premium BabyCare 's see"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content=". contact we today ! Data Screenshot : result deliver : how this Premium BabyCare 's achieve Scalable GrowthWith a structured advertising and optimization strategy , this Premium BabyCare 's see tangible result within a short timeframe : sale growth : scale from ₹ 80 lakh to ₹ 1 crore in revenue . advertising Efficiency : improve ACOS to 12 % , maximize profit margin . optimized budgeting : reduced spend on underperform ad while enhance ROI on high - convert product . ready to witness game - change result for your Amazon store ? let us start build your custom strategy today . Data Visualization : insight back by NumbersVisualizing success be just as important as achieve it . here ’ a breakdown of This Premium BabyCare 's ’s journey on Amazon : Sales Growth ( ₹ 80l → ₹ 1cr ) reduced ACOS to 12 % Higher Conversion Rates through Targeted AdvertisingWant to see similar growth for your brand ? book a free consultation now!optimize Content Strategy : drive Long - Term GrowthBeyond"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="ACOS to 12 % Higher Conversion Rates through Targeted AdvertisingWant to see similar growth for your brand ? book a free consultation now!optimize Content Strategy : drive Long - Term GrowthBeyond advertising , we optimize content element to ensure sustained performance : enhance product listing – seo - drive description , engage visual , and keyword - rich title . customer - Centric Approach – optimize Q&A section and review to build credibility . A+ Content & Storefront Optimization – increase engagement through premium content strategy . your content be your brand ’s voice on Amazon . let ’s optimize it for high visibility and conversion . conclusion : this Premium BabyCare 's ’s growth be just the BeginningThis Premium BabyCare 's ’s success story be proof that with the right strategy , data - drive decision - making , and continuous optimization , brand can achieve scalable growth on Amazon . if you ’re look to transform your e - commerce business , let ’s create a custom"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content=", data - drive decision - making , and continuous optimization , brand can achieve scalable growth on Amazon . if you ’re look to transform your e - commerce business , let ’s create a custom strategy tailor to your goal . contact we today!other ProjectsOther Case StudiesCheck our other project case study with detailed explanationsother ProjectsOther Case StudiesCheck our other project case study with detailed explanationsall ProjectsAll ProjectsCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%TACOSCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%tacoslearn MoreCase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="16%tacoslearn MoreCase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % tacoscase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % TACOSLearn MoreCase StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%case StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%learn MoreOther ProjectsOther Case StudiesCheck our other project case study with detailed explanationsall ProjectsCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="MoreOther ProjectsOther Case StudiesCheck our other project case study with detailed explanationsall ProjectsCase StudyHow a a skin care brand Reduced CPC by 27 % & Scaled Sales on AmazonThis Premium skin care brand Reduced CPC by 27 % & Scaled Sales on Amazon1 CroreMonthly Sales 16%tacoslearn MoreCase StudyThis Premium Clothing Brand 's Amazon Success Story : from Startup to Category LeaderA Data - back Growth Strategy that deliver exceptional results2.4 CroreMontly Sales achieve 7.6 % TACOSLearn MoreCase StudyScaling a plant protein brand on Amazon India with Regro mediaaco improve by 20 % & Single Digit TACOS Achieved-18.7%Single Digit TACOS achieved+18.8%adsale increase by 18.8%learn morelet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages &"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content=") +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri"),
#  Document(metadata={'source': 'https://www.regromedia.com/case-studies/how-this-premium-babycare-s-scaled-to-1-crore-sales-on-amazon-with-strategic-marketplace-optimization', 'title': 'Regro Media', 'description': 'Regro Media is a performance-driven Amazon Ads agency helping D2C brands and sellers maximize sales, visibility, and profitability on Amazon.', 'language': 'en'}, page_content="detailslet'stalk!last 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call Backsammy@regromedia.com(INDIA ) +91 8527769129/ +91 98739 44251regro Media , 23 , Old Tehri Road , Tehri Garhwal , Uttarakhand , India , 249145menuhomeservicescase studycontactservicesadvertise ManagementImages & CreativesTraining & CoachingSEO & Listing optimizationother PagesPrivacy PolicyFollow we : AboutTerms & ConditionsPrivacy PolicyRefund PolicyShipping PolicyPricing DetailsLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call backhomeservicescase StudyFree CoursesContactSchedule a calllast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a Call BackLast 30 Day Total SalesLast 30 Day ACOSBrand NameRecieve a call back")]

# %%
# Convert Text into vectors and store into Vector DB
# Embedding
embedding = OpenAIEmbeddings(model="text-embedding-3-large")
embedding

# Vector Store
vector_store = PineconeVectorStore.from_documents(
    documents=regro_media_data_chunks,
    embedding=embedding, 
    pinecone_api_key=os.environ.get("PINECONE_API_KEY"),
    index_name=os.environ.get("PINECONE_INDEX_NAME"),
    namespace="Regro_Media",
)
vector_store

# %%
# Conversation History STORE
STORE: Dict[str, ChatMessageHistory] = {}
MESSAGE_PAIR = 10  # keep last 10 Q&A pairs (20 messages)

# %%
def get_session_conversation_history(session_id: str) -> BaseChatMessageHistory:
    """
    Returns a ChatMessageHistory for this session_id.
    Also trims history to the last MESSAGE_PAIR turns.
    """
    if session_id not in STORE:
        STORE[session_id] = ChatMessageHistory()

    history = STORE[session_id]
    # Trim last N turns (20 messages)
    threshold = MESSAGE_PAIR * 2
    if len(history.messages) > threshold:
        history.messages = history.messages[-threshold:]
    return history

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """You are Regro Media's intelligent assistant, specialized in providing accurate, helpful answers about Regro Media's services, products, and information.

## Your Core Responsibilities:
- Answer questions using ONLY the provided context below
- Maintain conversation continuity by referencing chat history when relevant
- Provide detailed, well-structured responses that are easy to understand and visually engaging
- Be honest when information isn't available in the context

## Response Guidelines:

### Accuracy & Relevance:
- Base ALL answers strictly on the provided context
- If the answer isn't in the context, respond: "I don't have that information in my current knowledge base. Please contact Regro Media directly at [contact info] for assistance."
- Never make assumptions or provide information not present in the context
- Cross-reference chat history to understand follow-up questions and maintain context

### Formatting Standards:
- Use clear headings (###) to organize complex information
- Break down information into bullet points for maximum readability
- Use numbered lists for sequential steps or prioritized information
- Apply **bold** for key terms, important points, or emphasis
- **Use emojis liberally** to enhance visual appeal and improve scannability:
  * 📉 📈 for metrics, trends, and performance indicators
  * ✅ ✓ for confirmations, benefits, achievements, or positive points
  * 📌 for important notes or highlights
  * 💡 for tips, insights, or recommendations
  * ⚠️ ❗ for warnings or important considerations
  * 📞 ☎️ for contact information
  * 🔗 for links or references
  * 💰 💵 for financial results, revenue, or cost savings
  * 🎯 for goals or objectives
  * 🚀 for growth, scaling, or launch information
  * 📊 📈 for statistics and data points
  * 🔄 for processes or cycles
  * ⏱️ for time-related information
  * 🏆 for achievements or wins
  * 🛠️ for tools or technical features
  * 💼 for business-related information
  * 🌟 for highlights or special features

### Response Structure:
1. **Direct Answer First**: Start with a clear, concise answer to the question
2. **Supporting Details**: Provide relevant details using bullet points with emojis for visual hierarchy
3. **Additional Context**: Include related information that might be helpful
4. **Call-to-Action** (when appropriate): Guide users on next steps or where to find more information

### Tone & Style:
- Professional yet friendly and conversational
- Clear and concise - avoid unnecessary jargon
- Empathetic and helpful
- User-centric focus with visual engagement
- Make information scannable and easy to digest

### Example Response Format:
"**[Direct Answer to Question]**

### 📌 Key Points:
- ✅ Point 1 with relevant detail
- ✅ Point 2 with relevant detail
- ✅ Point 3 with relevant detail

### 💡 Additional Information:
[Any supplementary context that adds value]

### 🎯 Results/Benefits: (when applicable)
- 📈 Metric 1: [percentage/number]
- 📉 Metric 2: [percentage/number]
- 💰 Metric 3: [percentage/number]

### 🚀 Next Steps: (if applicable)
[Actionable guidance for the user]"

---

**Context:**
{context}

**Chat History:** Review previous messages to understand the conversation flow and any references to earlier topics.
""",
        ),
        MessagesPlaceholder(variable_name="chat_history"),
        ("human", "{question}"),
    ]
)

# %%
llm = ChatOpenAI(model="gpt-4o", temperature=0.0, max_completion_tokens=2000)

# %%
retriever = vector_store.as_retriever(
    search_type = "mmr",
    search_kwargs = {
        "k": 5,
        "fetch_k":20
    }
)

# %%
def docs_to_context(docs):
    """Combine retrieved docs into a single context string."""
    return "\n\n".join(doc.page_content for doc in docs)

# %%
rag_chain = (
    RunnableParallel(
        {
            # Take "question" → retrieve docs → turn into context string
            "context": itemgetter("question") | retriever | docs_to_context,
            # both question and chat_history injected from RunnableWithMessageHistory
            "question": itemgetter("question"),
            "chat_history": itemgetter("chat_history")
        }
    )
    | prompt
    | llm
)

# %%
# Add Automatic Conversation History
rag_with_history = RunnableWithMessageHistory(
    rag_chain,
    get_session_history=get_session_conversation_history,
    input_messages_key="question",
    history_messages_key="chat_history"
)
rag_with_history
# Out:
# RunnableWithMessageHistory(bound=RunnableBinding(bound=RunnableBinding(bound=RunnableAssign(mapper={
#   chat_history: RunnableBinding(bound=RunnableLambda(_enter_history), kwargs={}, config={'run_name': 'load_history'}, config_factories=[])
# }), kwargs={}, config={'run_name': 'insert_history'}, config_factories=[])
# | RunnableBinding(bound=RunnableLambda(_call_runnable_sync), kwargs={}, config={'run_name': 'check_sync_or_async'}, config_factories=[]), kwargs={}, config={'run_name': 'RunnableWithMessageHistory'}, config_factories=[]), kwargs={}, config={}, config_factories=[], get_session_history=<function get_session_conversation_history at 0x000002118CF0D300>, input_messages_key='question', history_messages_key='chat_history', history_factory_config=[ConfigurableFieldSpec(id='session_id', annotation=<class 'str'>, name='Session ID', description='Unique identifier for a session.', default='', is_shared=True, dependencies=None)])

# %%
conversational_chain = rag_with_history | StrOutputParser()

# %%
def answer_question(session_id: str, question: str) -> str:
    """
    Call this for each user message.
    session_id keeps conversations separate per user/tab/chat.
    """
    config = {"configurable": {"session_id": session_id}}

    result = conversational_chain.invoke(
        {"question": question},
        config=config,
    )
    return result

# %%
answer_question(
    session_id="user01_chat05",
    question="""What is the refund policy for regro""",
)
# Out:
# "**Refund Policy for Regro Media**\n\n### 📌 Key Points:\n- **Case-by-Case Basis**: Refunds are considered individually, based on specific circumstances.\n- **Eligibility for Refund**:\n  - If the service provided was not as described.\n  - If there was a technical issue preventing service delivery.\n- **Request Process**:\n  - Clients must contact Regro Media in writing.\n  - Provide a detailed explanation for the refund request.\n  - Regro Media will review the request and determine if a refund is warranted.\n- **Non-Refundable Situations**:\n  - Services that have already been completed.\n  - Violations of Regro Media's terms of service.\n  - Digital courses or training programs purchased at a discount or during a limited-time offer.\n\n### 🚀 Next Steps:\nFor any questions or concerns regarding the refund and cancellation policy, please contact Regro Media directly at 📞 Connect@regromedia.com. They will be happy to assist you."

# %% [markdown]
# Here are the case studies mentioned:\n\n1. A premium skincare brand reduced CPC by 27% and scaled sales on Amazon, achieving 1 crore in monthly sales with a 16% TACOS.\n2. A premium clothing brand's Amazon success story, achieving 2.4 crore in monthly sales with a 7.6% TACOS.\n3. Scaling a plant protein brand on Amazon India, achieving a 20% improvement in ACOS and single-digit TACOS.\n4. A baby care brand scaled to new heights with 123% growth in revenue and a 30% ROAS improvement.\n5. A body warmer brand saw sales growth with a 68% organic order increase and a 38.10% reduced CPC.\n6. Golden Bee brand scaled 4x in sales while maintaining TACOS under 10%.\n7. Fame Rugs on Amazon.com saw ACOS drop from 41.6% to 22% while total sales surged from $210k to $380.8k, an 81% increase.

# %% [markdown]
# Regro Media offers a variety of services, including campaign strategy, creative design, ad placement, and performance tracking. They also provide add-on services such as competitor analysis, keyword research, and product list optimization. These services are designed to create customized advertising campaigns that drive results and fit any budget.

# %% [markdown]
# Clients have provided positive feedback about Regro Media, highlighting their commitment to results and communication. They appreciate the clear performance reports, regular strategy updates, and the team's availability for feedback and campaign adjustments. Reviews mention that Regro Media steps up to resolve issues when things go wrong, making them a reliable and committed partner for Amazon sellers looking to scale their stores and drive measurable growth.

# %% [markdown]
# To solve the challenges faced by the skincare brand, Regro Media implemented a comprehensive, data-driven strategy:\n\n1. **Campaign Restructuring**: The ad campaigns were rebuilt for greater efficiency and scalability, ensuring that the brand's advertising efforts were streamlined and more effective.\n\n2. **High-Intent Keyword Targeting**: The focus was placed on targeting keywords with a proven track record of conversion, ensuring that the ad budget was spent on the most effective terms to drive sales.\n\n3. **CPC Optimization**: Bids were closely monitored and adjusted to reduce the cost per acquisition, helping to manage and lower the rising ad costs.\n\n4. **Balanced Growth**: Investments were made in improving organic ranking and conversion rates to reduce the brand's reliance on ad-driven sales, fostering a more sustainable growth model.\n\nThrough these strategies, the brand was able to reduce CPC by 27%, improve ACOS by 5.5 percentage points, increase clicks by 24%, and maintain stable sales with less ad spend, achieving a consistent 16% TACOS.

# %% [markdown]
# Following the implementation of Regro Media's strategy, the skincare brand achieved several significant results:\n\n1. **CPC Reduction**: The cost per click was reduced by 27%, which helped lower the overall advertising costs and improve the efficiency of the ad spend.\n\n2. **ACOS Improvement**: The advertising cost of sales (ACOS) improved by 5.5 percentage points, indicating a more effective use of the advertising budget in generating sales.\n\n3. **Increased Clicks**: There was a 24% increase in the number of clicks, reflecting higher engagement and interest from potential customers.\n\n4. **Stable Sales with Reduced Ad Spend**: The brand was able to maintain stable sales levels while spending less on advertising, showcasing the effectiveness of the optimized strategy.\n\n5. **Consistent TACOS**: The total advertising cost of sales (TACOS) remained stable at 16%, demonstrating a balanced approach between ad-driven and organic sales growth.

# %% [markdown]
# Here's how a skin care brand successfully reduced CPC by 27% and scaled sales on Amazon:\n\n### Challenges Faced:\n- Rising ad costs (CPC & ACOS).\n- Heavy reliance on ad-driven sales instead of organic growth.\n- Difficulty in expanding visibility in a crowded skincare market.\n\n### Strategy Implemented by Regro Media:\n- **Campaign Restructuring**: Rebuilt ad campaigns for efficiency and scalability.\n- **High-Intent Keyword Targeting**: Focused ad budget on proven converting keywords.\n- **CPC Optimization**: Closely monitored bids to reduce acquisition costs.\n- **Balanced Growth**: Invested in organic ranking and conversion to maintain a healthy TACOS.\n\n### Results Achieved in 4 Months:\n- 📉 **27% Lower CPC**: Reduced cost per click significantly.\n- 📈 **5.5 Percentage Point ACOS Improvement**: Enhanced advertising cost of sales.\n- 🔄 **24% More Clicks**: Higher engagement with ads.\n- 📊 **Stable 16% TACOS**: Ensured scalable and profitable growth.\n- 💰 **Sustained Sales**: Maintained sales while spending less on ads.\n\n### Conclusion:\nBy partnering with Regro Media, the skin care brand learned that growth on Amazon is not just about spending more—it's about spending smarter. With reduced CPC, improved ACOS, and a healthy ad-to-organic balance, the brand built a foundation for long-term growth in a highly competitive category.

# %% [markdown]
# **How a Skin Care Brand Reduced CPC by 27% & Scaled Sales on Amazon**\n\n### 📌 Key Points:\n- **Challenge**: The skin care brand faced rising ad costs (CPC & ACOS), heavy reliance on ad-driven sales, and difficulty expanding visibility in a crowded market.\n- **Strategy Implemented**:\n  - **Campaign Restructuring**: Rebuilt ad campaigns for efficiency and scalability.\n  - **High-Intent Keyword Targeting**: Focused ad budget on proven converting keywords.\n  - **CPC Optimization**: Closely monitored bids to reduce acquisition costs.\n  - **Balanced Growth**: Invested in organic ranking and conversion to maintain a healthy TACOS.\n\n### 💡 Additional Information:\n- **Results Achieved in 4 Months**:\n  - 📉 **27% Lower CPC**: Significant reduction in cost-per-click.\n  - 📈 **5.5 Percentage Point ACOS Improvement**: Enhanced advertising cost of sales.\n  - 📊 **24% More Clicks**: Higher engagement with ads.\n  - 📌 **Stable 16% TACOS**: Ensured scalable and profitable growth.\n  - 💰 **Spend Optimization**: Reduced ad spend from ₹13.7L (May) to ₹12.4L (Aug).\n\n### 🎯 Conclusion:\nBy partnering with Regro Media, the skin care brand learned that growth on Amazon is not just about spending more—it's about spending smarter. With reduced CPC, improved ACOS, and a healthy ad-to-organic balance, the brand built a foundation for long-term growth in a highly competitive category.

# %% [markdown]
# **Regro Media Team Members and Their Roles**\n\n### 📌 Key Team Members:\n- **Sammy Akthar**: Co-Founder\n- **Sandeep Sajwan**: Co-Founder\n- **Tapan Karan**: CMO cum HR\n- **Shilpa Arora**: PPC Specialist\n- **Deepak Kumar**: MIS\n- **Bharat Gavhane**: PPC Specialist\n- **Md. Ahmad**: PPC Specialist\n- **Muhammad Hamid**: PPC Specialist\n- **Tanishq Rathore**: PPC Specialist\n- **Ashwani Patel**: CXO\n- **Harsh Dev Sharma**: Appointment Setter\n- **Snehal Yogesh Ahirrao**: Marketing\n- **Prajakta Kapote**: Appointment Setter\n- **Razi Chaudhary**: SEO Specialist\n- **Vinay Chauhan**: PPC Specialist\n- **Dipanjan Das**: PPC Specialist\n- **Komal Sharma**: Marketing\n- **Marhama Kirmani**: Data Analyst\n- **Soniya Joshi**: Marketing\n- **PeddiReddy Venkatlakshmi**: Data Analyst\n- **Peddireddi Srinivas**: Appointment Setter\n- **Sagar Bhagchandani**: PPC Lead\n- **Mamta Sharma**: Data Analyst\n- **Hafeezur Rahman**: PR Head\n- **Chowdhury Aminurzaman**: Video Editor\n\n### 💡 How They Contribute to Growth and Client Satisfaction:\n- **Leadership & Strategy**: Co-Founders and CXO provide strategic direction and ensure alignment with client goals.\n- **PPC Specialists**: Optimize ad campaigns to improve performance metrics like CPC and ACOS, driving client sales growth.\n- **Marketing & SEO**: Enhance brand visibility and engagement through targeted marketing strategies and SEO optimization.\n- **Data Analysts**: Provide insights and analytics to inform decision-making and strategy adjustments.\n- **Appointment Setters**: Facilitate client communication and ensure timely follow-ups, enhancing client relationships.\n- **PR & Video Editing**: Manage public relations and create engaging content to support brand storytelling and client campaigns.\n\n### 🎯 Conclusion:\nEach team member plays a crucial role in ensuring Regro Media delivers exceptional service and results, fostering client satisfaction and long-term partnerships. By leveraging their expertise, Regro Media can effectively scale client businesses on platforms like Amazon.

# %% [markdown]
# **Refund Policy for Regro Media**\n\n### 📌 Key Points:\n- **Case-by-Case Basis**: Refunds are considered individually, based on specific circumstances.\n- **Eligibility for Refund**:\n  - If the service provided was not as described.\n  - If there was a technical issue preventing service delivery.\n- **Request Process**:\n  - Clients must contact Regro Media in writing.\n  - Provide a detailed explanation for the refund request.\n  - Regro Media will review the request and determine if a refund is warranted.\n- **Non-Refundable Situations**:\n  - Services that have already been completed.\n  - Violations of Regro Media's terms of service.\n  - Digital courses or training programs purchased at a discount or during a limited-time offer.\n\n### 🚀 Next Steps:\nFor any questions or concerns regarding the refund and cancellation policy, please contact Regro Media directly at 📞 Connect@regromedia.com. They will be happy to assist you.
